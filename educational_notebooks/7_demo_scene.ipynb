# %%
from src import *

# %%
glossy_red = PhongMaterial(
    name="glossy_red",
    base_color=Color.custom_rgb(255, 10, 40),
    spec_color=Color.custom_rgb(255, 255, 255),
    shininess=30,
    ior=1.5,
    reflectivity=0.2,
    transparency=0.0,
    normal_noise=PerlinNoise(
        scale=2.0,
        strength=0.1
    ),
)

glass_blue = PhongMaterial(
    name="glass_blue",
    base_color=Color.custom_rgb(10, 100, 255),
    spec_color=Color.custom_rgb(255, 255, 255),
    shininess=50,
    ior=1.5,
    reflectivity=0.1,
    transparency=0.9,
    normal_noise=PerlinNoise(
        scale=4.0,
        strength=0.1
    ),
)

sand = PhongMaterial(
    name="sand",
    base_color=Color.custom_rgb(210, 178, 128),
    spec_color=Color.custom_rgb(255, 255, 255),
    shininess=10,
    ior=1.3,
    reflectivity=0.0,
    transparency=0.0,
    normal_noise=PerlinNoise(
        scale=8.0,
        strength=0.08
    ),
)

wood = PhongMaterial(
    name="wood",
    base_color=Color.custom_rgb(139, 69, 19),
    spec_color=Color.custom_rgb(255, 255, 255),
    shininess=15,
    ior=1.4,
    reflectivity=0.1,
    transparency=0.0,
    normal_noise=PerlinNoise(
        scale=10.0,
        strength=0.1
    ),
)

rock = RockMaterial(
        base_color=Color.custom_rgb(110, 90, 90),
        spec_color=Color.custom_rgb(200, 210, 210),
        shininess=8,
        color_noise=FBMNoise(
            scale=2.0,
            strength=1.0,
            octaves=5,
            lacunarity=2.0,
            gain=0.5,
        ),
        normal_noise=TurbulenceNoise(
            scale=2.0,
            strength=0.5,
            octaves=5,
            lacunarity=2.0,
            gain=0.5,
        ),
        color_scale=3.0,
    )

golden = PhongMaterial(
    name="golden",
    base_color=Color.custom_rgb(255, 215, 0),
    spec_color=Color.custom_rgb(255, 255, 255),
    shininess=100,
    ior=0.47,
    reflectivity=0.8,
    transparency=0.0,
    normal_noise=PerlinNoise(
        scale=1.5,
        strength=0.05
    ),
)

diamond = PhongMaterial(
    name="diamond",
    base_color=Color.custom_rgb(210, 245, 255),
    spec_color=Color.custom_rgb(255, 255, 255),
    shininess=250,
    ior=2.42,
    reflectivity=0.08,
    transparency=0.92,
    normal_noise=TurbulenceNoise(
        scale=2.0,
        strength=0.1,
        octaves=4,
        lacunarity=2.0,
        gain=0.5
    ),
)

diamond2 = PhongMaterial(
    name="diamond",
    base_color=Color.custom_rgb(185, 242, 255),
    spec_color=Color.custom_rgb(255, 255, 255),
    shininess=300,
    ior=2.42,
    reflectivity=0.05,
    transparency=0.95,
    normal_noise=FBMNoise(
        scale=2.0,
        strength=0.1,
        octaves=4,
        lacunarity=2.0,
        gain=0.5
    ),
)


mirror = PhongMaterial(
    name="mirror",
    base_color=Color.custom_rgb(200, 200, 200),
    spec_color=Color.custom_rgb(255, 255, 255),
    shininess=500,
    ior=1.0,
    reflectivity=0.95,
)

bumpy_blue = PhongMaterial(
    name="bumpy_blue",
    base_color=Color.custom_rgb(30, 144, 255),
    spec_color=Color.custom_rgb(255, 255, 255),
    shininess=50,
    ior=1.5,
    reflectivity=0.3,
    transparency=0.0,
    normal_noise=PerlinNoise(
        scale=2.0,
        strength=0.2
    ),
)

marble = MarbleMaterial(
    name="marble",
    base_color=Color.custom_rgb(220, 220, 220),
    spec_color=Color.custom_rgb(255, 255, 255),
    light_color_factor = 0.1,
    dark_color_factor = 1.0,
    shininess=20,
    ior=1.5,
    reflectivity=0.1,
    transparency=0.0,
    normal_noise=TurbulenceNoise(
        scale=5.0,
        strength=0.1,
        octaves=4,
        lacunarity=2.0,
        gain=0.5
    ),
)

diamond_no_noise = PhongMaterial(
    base_color=Color.custom_rgb(210, 245, 255),
    spec_color=Color.custom_rgb(255, 255, 255),
    shininess=250,
    ior=2.42,
    reflectivity=0.08,
    transparency=0.92,
)

scene = Scene(
    camera=PinholeCamera(
        fov_deg=42,
        origin=Vertex(0.0, 0.8, 2.0),
        direction=Vector(0.0, -0.08, -1.0),
    ),
    objects=[
        # FLOOR
        Object(
            geometry=Square(
                vertex=Vertex(-1, 0, -1),
                diagonal_vertex=Vertex(1, 0, 1),
            ),
            material=marble,
        ).scale(8.0, 1.0, 10.0).translate(0, -1.0, -6.0),
        # CENTRAL PEDESTAL
        Object(
            geometry=Box(
                corner1=Vertex(-0.5, -0.5, -0.5),
                corner2=Vertex(0.5, 0.5, 0.5),
            ),
            material= golden,
        ).scale(1.7, 0.5, 1.7).translate(0.0, -0.7, -6.0),
        # HERO OBJECT - DIAMOND SPHERE
        Object(
            geometry=Sphere(
                center=Vertex(0, 0, 0),
                radius=1.0,
            ),
            material=diamond,
        ).scale(1.0, 1.0, 1.0).translate(0.0, 0.55, -6.0),
        # FLOATING RING AROUND HERO
        Object(
            geometry=Torus(
                center=Vertex(0, 0, 0),
                radius_major=1.5,
                radius_tube=0.12,
            ),
            material=golden,
        ).rotate_x(72).rotate_y(22).translate(0.0, 0.7, -6.0),
        # SECOND RING
        Object(
            geometry=Torus(
                center=Vertex(0, 0, 0),
                radius_major=1.1,
                radius_tube=0.08,
            ),
            material=mirror,
        ).rotate_y(90).rotate_z(25).translate(0.0, 0.7, -6.0),
        # LEFT GLASS SPHERE
        Object(
            geometry=Sphere(
                center=Vertex(0, 0, 0),
                radius=1.0,
            ),
            material=glass_blue,
        ).scale(0.75, 0.75, 0.75).translate(-2.25, -0.2, -4.6),
        # RIGHT MARBLE SPHERE
        Object(
            geometry=Sphere(
                center=Vertex(0, 0, 0),
                radius=1.0,
            ),
            material=marble,
        ).scale(0.72, 0.72, 0.72).translate(2.2, -0.28, -4.8),
        # FOREGROUND BLUE TORUS
        Object(
            geometry=Torus(
                center=Vertex(0, 0, 0),
                radius_major=0.7,
                radius_tube=0.16,
            ),
            material=bumpy_blue,
        ).rotate_x(90).rotate_z(18).translate(-1.0, -1.1, -3.1),
        # BACK WALL
        Object(
            geometry=Square(
                vertex=Vertex(-1, 0, -1),
                diagonal_vertex=Vertex(1, 0, 1),
            ),
            material=rock,
        ).scale(2.0, 10.0, 1.0).translate(0, 3.0, -12.0),
        # LEFT MIRROR PANEL
        Object(
            geometry=Square(
                vertex=Vertex(-1, 0, -1),
                diagonal_vertex=Vertex(1, 0, 1),
            ),
            material=mirror,
        ).scale(1.0, 1.0, 8.5).rotate_x(90).rotate_y(45).translate(-4.6, 1.0, -10.0),
        # RIGHT MIRROR PANEL
        Object(
            geometry=Square(
                vertex=Vertex(-1, 0, -1),
                diagonal_vertex=Vertex(1, 0, 1),
            ),
            material=mirror,
        ).scale(1.0, 1.0, 8.5).rotate_x(90).rotate_y(-45).translate(4.6, 1.0, -10.0),
        # SMALL FOREGROUND GOLD SPHERE
        Object(
            geometry=Sphere(
                center=Vertex(0, 0, 0),
                radius=1.0,
            ),
            material=golden,
        ).scale(0.33, 0.33, 0.33).translate(1.35, -0.67, -3.4),
        Object(
            geometry=Sphere(
                center=Vertex(0, 0, 0),
                radius=1.0,
            ),
            material=diamond_no_noise,
        ).scale(0.5, 0.5, 0.5).translate(0.0, 1.8, -3.5),
    ],
    lights=[
        # main warm key light
        PointLight(
            position=Vertex(3.5, 5.5, -1.0),
            intensity=1.0,
            color=Color.custom_rgb(255, 244, 230),
        ),

        # cool fill light
        PointLight(
            position=Vertex(-4.5, 2.8, -2.5),
            intensity=0.45,
            color=Color.custom_rgb(200, 220, 255),
        ),

        # pink rim / accent light
        PointLight(
            position=Vertex(0.0, 4.0, -10.5),
            intensity=0.8,
            color=Color.custom_rgb(255, 180, 220),
        ),

        # extra low front fill
        PointLight(
            position=Vertex(0.0, 0.8, 1.0),
            intensity=0.18,
            color=Color.custom_rgb(255, 255, 255),
        ),
    ],
    skybox="./skyboxes/shanghai_4k.hdr"
)
scene.validate()

render_configuration = RenderConfig(
    resolution=Resolution.R720p,
    samples_per_pixel=20,
    max_depth=5,
)

# %%
my_ray_tracer = MultiProcessRowRenderLoop(scene=scene, render_config=render_configuration)
png_path = my_ray_tracer.render("images/perlin_noise.png")
