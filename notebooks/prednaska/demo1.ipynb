# %%
from src.material.textures.noise.perlin_noise import PerlinNoise
from src.render.loops.progress import PreviewConfig, ProgressDisplay
from src.render.render_config import RenderConfig
from src.render import LinearRayCaster
from src.geometry.primitives.box import Box
from src.geometry.primitives.torus import Torus
from src.geometry.primitives.cylinder import Cylinder
from src.scene.object import Object
from src.material.material.phong_material import PhongMaterial
from src import Color, Camera, Resolution, Vertex, PointLight, Vector, Scene, Square, Sphere, Triangle, AmbientLight

# ── helpers ────────────────────────────────────────────────────────────────────

WHITE = Color.custom_rgb(255, 255, 255)
BLACK = Color.custom_rgb(0, 0, 0)
RES   = Resolution.R360p

def M(name, base, *, shin=32, ior=1.5, refl=0.0, transp=0.0, nscale=None, nstr=0.0):
    return PhongMaterial(
        name=name, base_color=base, spec_color=WHITE,
        shininess=shin, ior=ior, reflectivity=refl, transparency=transp,
        normal_noise=None if nscale is None else PerlinNoise(scale=nscale, strength=nstr),
    )

def render(scene_fn, filename, *, res=RES, spp=1, depth=5):
    scene = scene_fn()
    LinearRayCaster(
        scene=scene,
        render_config=RenderConfig(resolution=res, samples_per_pixel=spp, max_depth=depth),
        preview_config=PreviewConfig(progress_display=ProgressDisplay.TQDM_IMAGE_PREVIEW),
    ).render(filename)

def row_of_spheres(materials, z=-8, y=0, spacing=2.0) -> list[Object]:
    n = len(materials)
    xs = [i * spacing - (n - 1) * spacing / 2 for i in range(n)]
    return [Object(Sphere(Vertex(x, y, z), 1.0), m) for x, m in zip(xs, materials)]

def default_floor(mat=None):
    mat = mat or M("floor", Color.custom_rgb(200, 200, 200), shin=5)
    return Object(Square(Vertex(-10, -1, -25), Vertex(10, -1, 5)), mat)

def default_camera(z=0):
    return Camera(
        fov_deg=75,
        aspect_ratio=Resolution.custom(width=600, height=200).aspect_ratio,
        origin=Vertex(0, 0, z),
        direction=Vector(0, 0, -1),
    )

def default_lights(*, key_pos=Vertex(0, 4, 0), key_intensity=800.0, ambient=0.15):
    return [
        PointLight(position=key_pos, intensity=key_intensity, falloff=0.0015),
        AmbientLight(intensity=ambient),
    ]

# ── scenes ─────────────────────────────────────────────────────────────────────

def test_shininess():
    """Shininess 0→512: specular highlight should shrink and sharpen."""
    values = [0, 8, 32, 128, 512]
    mats = [M(f"shin_{v}", Color.custom_rgb(30, 30, 30), shin=v) for v in values]
    return Scene(camera=default_camera(), lights=default_lights(),
                 objects=[default_floor(), *row_of_spheres(mats)])

def test_reflectivity():
    """Reflectivity 0→1: surface should go from matte to perfect mirror."""
    values = [0.0, 0.25, 0.5, 0.75, 1.0]
    mats = [M(f"refl_{v}", Color.custom_rgb(180, 60, 60), shin=64, refl=v) for v in values]
    return Scene(camera=default_camera(), lights=default_lights(),
                 objects=[default_floor(), *row_of_spheres(mats)])

def test_transparency():
    """Transparency 0→1: sphere should go from opaque to invisible."""
    values = [0.0, 0.25, 0.5, 0.75, 1.0]
    colors = [
        Color.custom_rgb(255, 60, 60),
        Color.custom_rgb(255, 140, 0),
        Color.custom_rgb(60, 200, 60),
        Color.custom_rgb(60, 60, 255),
        Color.custom_rgb(180, 60, 255),
    ]
    mats = [M(f"transp_{v}", c, shin=64, ior=1.5, transp=v) for v, c in zip(values, colors)]
    checker = M("checker_floor", Color.custom_rgb(10, 169, 224), shin=5)
    return Scene(camera=default_camera(), lights=default_lights(),
                 objects=[default_floor(checker), *row_of_spheres(mats)])

def test_ior():
    """IOR 1.0→2.4: refraction should bend more with higher IOR."""
    values = [1.0, 1.3, 1.5, 1.7, 2.4]
    colors = [
        Color.custom_rgb(255, 100, 100),
        Color.custom_rgb(100, 255, 100),
        Color.custom_rgb(100, 100, 255),
        Color.custom_rgb(255, 255, 100),
        Color.custom_rgb(100, 255, 255),
    ]
    mats = [M(f"ior_{v}", c, shin=128, ior=v, transp=0.9) for v, c in zip(values, colors)]
    checker = M("checker_floor", Color.custom_rgb(10, 169, 224), shin=5)
    return Scene(camera=default_camera(), lights=default_lights(),
                 objects=[default_floor(checker), *row_of_spheres(mats)])

def test_refl_transp_combined():
    """Both reflectivity and transparency: glass-like materials."""
    mats = [
        M("glass_low",  Color.custom_rgb(200, 230, 255), shin=128, ior=1.5, refl=0.05, transp=0.9),
        M("glass_mid",  Color.custom_rgb(200, 255, 200), shin=128, ior=1.5, refl=0.1,  transp=0.7),
        M("glass_high", Color.custom_rgb(255, 200, 200), shin=128, ior=1.5, refl=0.2,  transp=0.5),
        M("diamond",    Color.custom_rgb(185, 242, 255), shin=300, ior=2.42,refl=0.1,  transp=0.95),
        M("mirror",     Color.custom_rgb(200, 200, 200), shin=500, ior=1.0, refl=1.0),
    ]
    return Scene(camera=default_camera(), lights=default_lights(),
                 objects=[default_floor(), *row_of_spheres(mats)])

def test_normal_noise():
    """Normal noise scale and strength: surface should look bumpier."""
    configs = [(1, 0.05), (2, 0.1), (4, 0.2), (6, 0.3), (8, 0.5)]
    mats = [M(f"noise_{s}_{st}", Color.custom_rgb(100, 150, 255), shin=32, nscale=s, nstr=st)
            for s, st in configs]
    return Scene(camera=default_camera(), lights=default_lights(),
                 objects=[default_floor(), *row_of_spheres(mats)])

def test_depth():
    """Reflection depth: mirror ball inside mirror box should show recursion."""
    mirror = M("mirror", Color.custom_rgb(220, 220, 220), shin=500, refl=0.95)
    ball   = M("ball",   Color.custom_rgb(255, 80, 80),   shin=64,  refl=0.3)
    return Scene(
        camera=default_camera(),
        lights=default_lights(key_pos=Vertex(0, 3, -5), ambient=0.3),
        objects=[
            default_floor(),
            Object(Sphere(Vertex(0, 0, -7), 1.0), ball),
            Object(Sphere(Vertex(-3, 0, -7), 1.0), mirror),
            Object(Sphere(Vertex(3, 0, -7), 1.0), mirror),
        ]
    )

def test_geometry():
    """All geometry types with same neutral material."""
    mat  = M("neutral", Color.custom_rgb(180, 180, 200), shin=32, refl=0.1)
    floor = M("floor",  Color.custom_rgb(200, 200, 200), shin=5)
    return Scene(
        camera=default_camera(),
        lights=default_lights(),
        objects=[
            default_floor(floor),
            Object(Sphere(Vertex(-4, 0, -8), 0.8), mat),
            Object(Cylinder(Vertex(-2, -1, -8), Vertex(-2, 1, -8), 0.6), mat),
            Object(Torus(Vertex(0, 0, -8), 0.7, 0.25), mat),
            Object(Box(Vertex(1.2, -0.8, -8.8), Vertex(2.8, 0.8, -7.2)), mat),
            Object(Triangle(Vertex(3.5, -1, -8), Vertex(4.5, 1, -7.5), Vertex(5.5, -1, -8)), mat),
        ]
    )

def test_lighting():
    """Multiple lights: color mixing, shadow casting, falloff."""
    mat   = M("white", Color.custom_rgb(220, 220, 220), shin=32)
    floor = M("floor", Color.custom_rgb(50, 50, 50), shin=5)
    return Scene(
        camera=default_camera(),
        lights=[
            PointLight(position=Vertex(-3, 3, -5), intensity=600.0, falloff=0.002),
            PointLight(position=Vertex(3, 3, -5),  intensity=600.0, falloff=0.002),
            AmbientLight(intensity=0.05),
        ],
        objects=[
            default_floor(floor),
            *row_of_spheres([mat, mat, mat], z=-8, spacing=3.0),
        ]
    )

def test_mixed_demo():
    """Kitchen sink: all features combined."""
    return Scene(
        camera=default_camera(),
        lights=default_lights(key_pos=Vertex(2, 5, -3), key_intensity=1000.0),
        objects=[
            default_floor(M("sand", Color.custom_rgb(210, 178, 128), shin=10, ior=1.3, nscale=8, nstr=0.08)),
            Object(Sphere(Vertex(-0.5, 0.2, -6), 1.0),   M("diamond",  Color.custom_rgb(185, 242, 255), shin=300, ior=2.42, refl=0.1, transp=0.95)),
            Object(Triangle(Vertex(2,0,-8), Vertex(3,1.5,-7), Vertex(4,0,-8)), M("mirror", Color.custom_rgb(200,200,200), shin=500, refl=1.0)),
            Object(Cylinder(Vertex(-0.5,-0.6,-2.0), Vertex(-0.9,0.6,-2.2), 0.4), M("glass", Color.custom_rgb(10,100,255), shin=50, refl=0.1, transp=0.9)),
            Object(Torus(Vertex(1,-0.85,-2.85), 0.6, 0.15), M("bumpy", Color.custom_rgb(30,144,255), shin=50, refl=0.3, nscale=3, nstr=0.2)),
            Object(Box(Vertex(-6,-0.7,-10), Vertex(-3,1,-8)),  M("glossy", Color.custom_rgb(255,10,40), shin=30, refl=0.2, nscale=2, nstr=0.1)),
            Object(Triangle(Vertex(7,1,-11), Vertex(3,4,-11), Vertex(1,-0.7,-9)), M("gold", Color.custom_rgb(255,215,0), shin=100, refl=0.8)),
        ]
    )

# ── run all ────────────────────────────────────────────────────────────────────

TESTS = {
    "shininess":        (test_shininess,          1, 5),
    "reflectivity":     (test_reflectivity,        1, 5),
    "transparency":     (test_transparency,        1, 5),
    "ior":              (test_ior,                 1, 5),
    "refl_transp":      (test_refl_transp_combined,1, 5),
    "normal_noise":     (test_normal_noise,        1, 5),
    "depth":            (test_depth,               1, 8),  # more bounces for mirror test
    "geometry":         (test_geometry,            1, 5),
    "lighting":         (test_lighting,            1, 5),
    "mixed":            (test_mixed_demo,          1, 5),
}

if __name__ == "__main__":
    for name, (fn, spp, depth) in TESTS.items():
        print(f"\n── rendering {name} ──")
        render(fn, f"{name}.png", spp=spp, depth=depth)
# Out:
# ── rendering shininess ──
# ...
# ── rendering reflectivity ──
# ...
# ── rendering transparency ──
# ...
# ── rendering ior ──
# ...
# ── rendering refl_transp ──
# ...
# ── rendering normal_noise ──
# ...
# ── rendering depth ──
# ...
# ── rendering geometry ──
# ...
# ── rendering lighting ──
# ...
# ── rendering mixed ──
# ...
